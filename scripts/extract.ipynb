# %%
from utils import file_to_df, read_prompt, extract_multi_async
import extractors

from functools import partial
import logging, sys

import pandas as pd

logging.basicConfig(
    level=logging.ERROR,
    stream=sys.stdout
)
# Out:
# Logfire project URL: https://logfire-us.pydantic.dev/tdpearson/oclc-agent

# %%
loaded_data = file_to_df("../data/input/KerrMcGeeMetadataSetAITest.xlsx")

# %%
process = partial(
    extract_multi_async,
    system_prompt=read_prompt("candidates"),
    extractor=extractors.Candidates,
    record_contents=loaded_data["Description (Islandora)"]
)

# %%
#loaded_data['Subjects_GPT-OSS'] = pd.Series(await process(model="gpt-oss"))
loaded_data['Subjects_GEMMA4'] = pd.Series(await process(model="gemma4"))
#loaded_data['Subjects_QWEN3'] = pd.Series(await process(model="bedrock/qwen.qwen3-coder-30b-a3b-v1:0"))
# Out:
# 16:47:22.291 Candidate extraction (async)
# 16:47:22.743   Chat Completion with 'gemma4' [LLM]
# 16:47:22.744 Candidate extraction (async)
# 16:47:22.745   Chat Completion with 'gemma4' [LLM]
# 16:47:22.746 Candidate extraction (async)
# 16:47:22.748   Chat Completion with 'gemma4' [LLM]
# 16:47:22.748 Candidate extraction (async)
# 16:47:22.750   Chat Completion with 'gemma4' [LLM]
# 16:47:22.757 Candidate extraction (async)
# 16:47:22.758   Chat Completion with 'gemma4' [LLM]
# 16:47:22.759 Candidate extraction (async)
# 16:47:22.760   Chat Completion with 'gemma4' [LLM]
# 16:47:22.761 Candidate extraction (async)
# 16:47:22.762   Chat Completion with 'gemma4' [LLM]
# 16:47:22.763 Candidate extraction (async)
# 16:47:22.764   Chat Completion with 'gemma4' [LLM]
# 16:47:22.766 Candidate extraction (async)
# 16:47:22.767   Chat Completion with 'gemma4' [LLM]
# 16:47:22.768 Candidate extraction (async)
# 16:47:22.770   Chat Completion with 'gemma4' [LLM]
# 16:47:22.771 Candidate extraction (async)
# 16:47:22.772   Chat Completion with 'gemma4' [LLM]
# 16:47:22.773 Candidate extraction (async)
# 16:47:22.774   Chat Completion with 'gemma4' [LLM]
# 16:47:22.775 Candidate extraction (async)
# 16:47:22.776   Chat Completion with 'gemma4' [LLM]
# 16:47:22.776 Candidate extraction (async)
# 16:47:22.777   Chat Completion with 'gemma4' [LLM]
# 16:47:22.778 Candidate extraction (async)
# 16:47:22.779   Chat Completion with 'gemma4' [LLM]
# 16:47:22.780 Candidate extraction (async)
# 16:47:22.781   Chat Completion with 'gemma4' [LLM]
# 16:47:22.782 Candidate extraction (async)
# 16:47:22.783   Chat Completion with 'gemma4' [LLM]
# 16:47:22.783 Candidate extraction (async)
# 16:47:22.792   Chat Completion with 'gemma4' [LLM]
# 16:47:22.792 Candidate extraction (async)
# 16:47:22.793   Chat Completion with 'gemma4' [LLM]
# 16:47:22.794 Candidate extraction (async)
# 16:47:22.795   Chat Completion with 'gemma4' [LLM]
# 16:47:22.796 Candidate extraction (async)
# 16:47:22.797   Chat Completion with 'gemma4' [LLM]
# 16:47:22.798 Candidate extraction (async)
# 16:47:22.799   Chat Completion with 'gemma4' [LLM]
# 16:47:22.800 Candidate extraction (async)
# 16:47:22.800   Chat Completion with 'gemma4' [LLM]
# 16:47:22.801 Candidate extraction (async)
# 16:47:22.803   Chat Completion with 'gemma4' [LLM]
# 16:47:22.804 Candidate extraction (async)
# 16:47:22.805   Chat Completion with 'gemma4' [LLM]
# 16:47:22.806 Candidate extraction (async)
# 16:47:22.807   Chat Completion with 'gemma4' [LLM]
# 16:47:22.808 Candidate extraction (async)
# 16:47:22.809   Chat Completion with 'gemma4' [LLM]
# 16:47:22.810 Candidate extraction (async)
# 16:47:22.811   Chat Completion with 'gemma4' [LLM]
# 16:47:22.812 Candidate extraction (async)
# 16:47:22.814   Chat Completion with 'gemma4' [LLM]
# 16:47:22.815 Candidate extraction (async)
# 16:47:22.817   Chat Completion with 'gemma4' [LLM]
# 16:47:22.818 Candidate extraction (async)
# 16:47:22.819   Chat Completion with 'gemma4' [LLM]
# 16:47:22.820 Candidate extraction (async)
# 16:47:22.821   Chat Completion with 'gemma4' [LLM]
# 16:47:22.822 Candidate extraction (async)
# 16:47:22.824   Chat Completion with 'gemma4' [LLM]
# 16:47:22.825 Candidate extraction (async)
# 16:47:22.826   Chat Completion with 'gemma4' [LLM]
# 16:47:22.827 Candidate extraction (async)
# 16:47:22.828   Chat Completion with 'gemma4' [LLM]
# 16:47:22.829 Candidate extraction (async)
# 16:47:22.831   Chat Completion with 'gemma4' [LLM]
# 16:47:22.831 Candidate extraction (async)
# 16:47:22.833   Chat Completion with 'gemma4' [LLM]
# 16:47:22.834 Candidate extraction (async)
# 16:47:22.835   Chat Completion with 'gemma4' [LLM]
# 16:47:22.836 Candidate extraction (async)
# 16:47:22.837   Chat Completion with 'gemma4' [LLM]
# 16:47:22.838 Candidate extraction (async)
# 16:47:22.839   Chat Completion with 'gemma4' [LLM]
# 16:47:22.840 Candidate extraction (async)
# 16:47:22.841   Chat Completion with 'gemma4' [LLM]
# 16:47:22.842 Candidate extraction (async)
# 16:47:22.843   Chat Completion with 'gemma4' [LLM]
# 16:47:22.845 Candidate extraction (async)
# 16:47:22.846   Chat Completion with 'gemma4' [LLM]
# 16:47:22.849 Candidate extraction (async)
# 16:47:22.851   Chat Completion with 'gemma4' [LLM]
# 16:47:22.854 Candidate extraction (async)
# 16:47:22.856   Chat Completion with 'gemma4' [LLM]
# 16:47:22.860 Candidate extraction (async)
# 16:47:22.862   Chat Completion with 'gemma4' [LLM]
# 16:47:22.865 Candidate extraction (async)
# 16:47:22.868   Chat Completion with 'gemma4' [LLM]
# 16:47:22.871 Candidate extraction (async)
# 16:47:22.873   Chat Completion with 'gemma4' [LLM]
# 16:47:22.876 Candidate extraction (async)
# 16:47:22.878   Chat Completion with 'gemma4' [LLM]
# 16:47:22.880 Candidate extraction (async)
# 16:47:22.883   Chat Completion with 'gemma4' [LLM]
# 16:47:22.885 Candidate extraction (async)
# 16:47:22.886   Chat Completion with 'gemma4' [LLM]
# 16:47:22.887 Candidate extraction (async)
# 16:47:22.889   Chat Completion with 'gemma4' [LLM]
# 16:47:22.890 Candidate extraction (async)
# 16:47:22.891   Chat Completion with 'gemma4' [LLM]
# 16:47:22.894 Candidate extraction (async)
# 16:47:22.895   Chat Completion with 'gemma4' [LLM]
# 16:47:22.898 Candidate extraction (async)
# 16:47:22.900   Chat Completion with 'gemma4' [LLM]
# 16:47:22.902 Candidate extraction (async)
# 16:47:22.903   Chat Completion with 'gemma4' [LLM]
# 16:47:22.905 Candidate extraction (async)
# 16:47:22.907   Chat Completion with 'gemma4' [LLM]
# 16:47:22.910 Candidate extraction (async)
# 16:47:22.912   Chat Completion with 'gemma4' [LLM]
# 16:47:22.915 Candidate extraction (async)
# 16:47:22.917   Chat Completion with 'gemma4' [LLM]
# 16:47:22.918 Candidate extraction (async)
# 16:47:22.920   Chat Completion with 'gemma4' [LLM]
# 16:47:22.921 Candidate extraction (async)
# 16:47:22.922   Chat Completion with 'gemma4' [LLM]
# 16:47:22.924 Candidate extraction (async)
# 16:47:22.925   Chat Completion with 'gemma4' [LLM]
# 16:47:22.926 Candidate extraction (async)
# 16:47:22.928   Chat Completion with 'gemma4' [LLM]
# 16:47:22.930 Candidate extraction (async)
# 16:47:22.934   Chat Completion with 'gemma4' [LLM]
# 16:47:22.936 Candidate extraction (async)
# 16:47:22.938   Chat Completion with 'gemma4' [LLM]
# 16:47:22.943 Candidate extraction (async)
# 16:47:22.947   Chat Completion with 'gemma4' [LLM]
# 16:47:22.950 Candidate extraction (async)
# 16:47:22.952   Chat Completion with 'gemma4' [LLM]
# 16:47:22.955 Candidate extraction (async)
# 16:47:22.957   Chat Completion with 'gemma4' [LLM]
# 16:47:22.958 Candidate extraction (async)
# 16:47:22.960   Chat Completion with 'gemma4' [LLM]
# 16:47:22.961 Candidate extraction (async)
# 16:47:22.964   Chat Completion with 'gemma4' [LLM]
# 16:47:22.967 Candidate extraction (async)
# 16:47:22.970   Chat Completion with 'gemma4' [LLM]
# 16:47:22.972 Candidate extraction (async)
# 16:47:22.974   Chat Completion with 'gemma4' [LLM]
# 16:47:22.977 Candidate extraction (async)
# 16:47:22.981   Chat Completion with 'gemma4' [LLM]
# 16:47:22.985 Candidate extraction (async)
# 16:47:22.990   Chat Completion with 'gemma4' [LLM]
# 16:47:22.992 Candidate extraction (async)
# 16:47:22.995   Chat Completion with 'gemma4' [LLM]
# 16:47:22.998 Candidate extraction (async)
# 16:47:23.000   Chat Completion with 'gemma4' [LLM]
# 16:47:23.002 Candidate extraction (async)
# 16:47:23.005   Chat Completion with 'gemma4' [LLM]
# 16:47:23.006 Candidate extraction (async)
# 16:47:23.008   Chat Completion with 'gemma4' [LLM]
# 16:47:23.012 Candidate extraction (async)
# 16:47:23.015   Chat Completion with 'gemma4' [LLM]
# 16:47:23.019 Candidate extraction (async)
# 16:47:23.025   Chat Completion with 'gemma4' [LLM]
# 16:47:23.027 Candidate extraction (async)
# 16:47:23.031   Chat Completion with 'gemma4' [LLM]
# 16:47:23.035 Candidate extraction (async)
# 16:47:23.037   Chat Completion with 'gemma4' [LLM]
# 16:47:23.041 Candidate extraction (async)
# 16:47:23.044   Chat Completion with 'gemma4' [LLM]
# 16:47:23.049 Candidate extraction (async)
# 16:47:23.051   Chat Completion with 'gemma4' [LLM]
# 16:47:23.054 Candidate extraction (async)
# 16:47:23.057   Chat Completion with 'gemma4' [LLM]
# 16:47:23.060 Candidate extraction (async)
# 16:47:23.063   Chat Completion with 'gemma4' [LLM]
# 16:47:23.066 Candidate extraction (async)
# 16:47:23.069   Chat Completion with 'gemma4' [LLM]
# 16:47:23.072 Candidate extraction (async)
# 16:47:23.075   Chat Completion with 'gemma4' [LLM]
# 16:47:23.078 Candidate extraction (async)
# 16:47:23.081   Chat Completion with 'gemma4' [LLM]
#              Candidate extraction (async)
# 16:47:27.605   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:27.616   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:27.624   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:27.867   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:27.914   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:28.034   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:28.259   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:28.288   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:28.356   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:28.427   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:28.435   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:28.699   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:28.744   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:28.868   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:28.909   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:28.917   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:28.945   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.175   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.322   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.341   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.450   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.732   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.773   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.784   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.807   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.884   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.902   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.910   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.927   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:29.972   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:30.059   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:30.152   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:30.227   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:30.606   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:30.668   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:30.978   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.137   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.255   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.447   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.460   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.523   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.585   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.605   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.673   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.684   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.751   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.895   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.899   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:31.910   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.049   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.119   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.188   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.197   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.207   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.243   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.254   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.268   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.296   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.343   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.530   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.577   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.587   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.634   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.644   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.706   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.718   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.848   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.915   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.922   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.927   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:32.992   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:33.194   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:33.266   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:33.334   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:33.460   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:33.631   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:33.689   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:33.752   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:33.767   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:33.807   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:33.924   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:33.980   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:34.147   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:34.203   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:34.258   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:34.477   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:34.629   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:34.792   Pydantic Candidates validate_python
#              Candidate extraction (async)
# 16:47:36.079   Pydantic Candidates validate_python

# %%
loaded_data.to_csv("../data/output/metadata.csv", index=False)

# %%
loaded_data
# Out:
#    Physical Collection Name (Islandora) Unique ID# (Islandora)  \
# 0     Kerr-McGee Corporation collection        WHC-P-2232_0006
# 1     Kerr-McGee Corporation collection        WHC-P-2232_0007
# 2     Kerr-McGee Corporation collection        WHC-P-2232_0008
# 3     Kerr-McGee Corporation collection        WHC-P-2232_0011
# 4     Kerr-McGee Corporation collection        WHC-P-2232_0012
# ..                                  ...                    ...
# 84    Kerr-McGee Corporation collection        WHC-P-2232_0139
# 85    Kerr-McGee Corporation collection        WHC-P-2232_0140
# 86    Kerr-McGee Corporation collection        WHC-P-2232_0143
# 87    Kerr-McGee Corporation collection        WHC-P-2232_0144
# 88    Kerr-McGee Corporation collection        WHC-P-2232_0149
#
#                                     Title (Islandora)  \
# 0   Kerr Inn Service gas station in Oklahoma City,...
# 1   Kerr-McGee service station in Oklahoma City, O...
# 2                           Deep Rock service station
# 3           Three workers on drilling rig drill floor
# 4   Big Hole Drilling drill bit and workers in Gra...
# ..                                                ...
# 84        Kerr-McGee Tower in Oklahoma City, Oklahoma
# 85        Kerr-McGee Tower in Oklahoma City, Oklahoma
# 86               Kerr McGee Building in Oklahoma City
# 87  Kerr-McGee Corporation tank car at the Kerr-Mc...
# 88  Cato Oil and Grease Company facility and autom...
#
#                               Description (Islandora) Date (Islandora)  \
# 0   Black and white photograph depicting the Kerr ...       circa 1937
# 1   Color photograph depicting a Kerr-McGee servic...             1976
# 2   Color photograph of a woman in an automobile a...  circa 1955-1959
# 3   Black and white photograph of three unidentifi...  circa 1970-1985
# 4   Black and white photograph of a Big Hole Drill...             1969
# ..                                                ...              ...
# 84  Color photograph depicting the Kerr-McGee Towe...  circa 1972-1973
# 85  Black and white photograph undated photograph ...  circa 1973-1985
# 86  Black and white photograph depicting the forme...  circa 1929-1940
# 87  Black and white photograph showing a Kerr-McGe...             1975
# 88  Black and white photograph depicting the Cato ...             1922
#
#                                     Notes (Islandora)  Subject (Islandora)  \
# 0                                                 NaN                  NaN
# 1                                                 NaN                  NaN
# 2   The Kerr-McGee Corporation purchased Deep Rock...                  NaN
# 3                                                 NaN                  NaN
# 4   Big Hole Drillers, a Kerr-McGee Corporation su...                  NaN
# ..                                                ...                  ...
# 84                                                NaN                  NaN
# 85                                                NaN                  NaN
# 86                                                NaN                  NaN
# 87                                                NaN                  NaN
# 88                                                NaN                  NaN
#
#     Location (Geographic) (Islandora)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 84                                NaN
# 85                                NaN
# 86                                NaN
# 87                                NaN
# 88                                NaN
#
#                                       Subjects_GEMMA4
# 0   corporate_name: Kerr Inn Service | form_genre:...
# 1   corporate_name: Kerr-McGee Corporation | corpo...
# 2   corporate_name: Deep Rock | form_genre: Color ...
# 3   form_genre: Black-and-white photographs | form...
# 4   chronological: 1969 | corporate_name: Big Hole...
# ..                                                ...
# 84  corporate_name: Kerr-McGee Corporation | form_...
# 85  corporate_name: Kerr-McGee Corporation | form_...
# 86  corporate_name: Kerr-McGee Corporation | form_...
# 87  chronological: 1975 | corporate_name: Kerr-McG...
# 88  chronological: 1922 | corporate_name: Cato Oil...
#
# [89 rows x 9 columns]
