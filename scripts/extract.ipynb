# %%
from utils import file_to_df, read_prompt, extract_multi_async
import extractors

from functools import partial
import logging, sys

import pandas as pd

logging.basicConfig(
    level=logging.INFO,
    stream=sys.stdout
)
# Out:
# Logfire project URL: https://logfire-us.pydantic.dev/tdpearson/oclc-agent

# %%
loaded_data = file_to_df("../data/input/KerrMcGeeMetadataSetAITest.xlsx")

# %%
process = partial(
    extract_multi_async,
    system_prompt=read_prompt("Extract_OCLC"),
    extractor=extractors.OclcFast,
    record_contents=loaded_data["Description (Islandora)"]
)

# %%
loaded_data['Subjects_GPT-OSS'] = pd.Series(await process(model="gpt-oss"))
loaded_data['Subjects_GEMMA4'] = pd.Series(await process(model="gemma4"))
#loaded_data['Subjects_QWEN3'] = pd.Series(await process(model="bedrock/qwen.qwen3-coder-30b-a3b-v1:0"))
# Out:
# 14:28:55.674 LLM extraction (async)
# 14:28:56.609   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.613 LLM extraction (async)
# 14:28:56.615   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.617 LLM extraction (async)
# 14:28:56.619   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.620 LLM extraction (async)
# 14:28:56.621   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.634 LLM extraction (async)
# 14:28:56.635   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.636 LLM extraction (async)
# 14:28:56.638   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.639 LLM extraction (async)
# 14:28:56.641   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.642 LLM extraction (async)
# 14:28:56.644   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.645 LLM extraction (async)
# 14:28:56.647   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.649 LLM extraction (async)
# 14:28:56.651   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.652 LLM extraction (async)
# 14:28:56.653   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.654 LLM extraction (async)
# 14:28:56.655   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.657 LLM extraction (async)
# 14:28:56.658   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.659 LLM extraction (async)
# 14:28:56.661   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.663 LLM extraction (async)
# 14:28:56.664   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.666 LLM extraction (async)
# 14:28:56.667   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.668 LLM extraction (async)
# 14:28:56.669   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.689 LLM extraction (async)
# 14:28:56.692   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.695 LLM extraction (async)
# 14:28:56.697   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.698 LLM extraction (async)
# 14:28:56.700   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.701 LLM extraction (async)
# 14:28:56.703   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.704 LLM extraction (async)
# 14:28:56.705   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.706 LLM extraction (async)
# 14:28:56.708   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.710 LLM extraction (async)
# 14:28:56.711   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.713 LLM extraction (async)
# 14:28:56.715   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.717 LLM extraction (async)
# 14:28:56.718   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.719 LLM extraction (async)
# 14:28:56.720   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.721 LLM extraction (async)
# 14:28:56.723   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.724 LLM extraction (async)
# 14:28:56.725   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.726 LLM extraction (async)
# 14:28:56.728   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.729 LLM extraction (async)
# 14:28:56.731   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.733 LLM extraction (async)
# 14:28:56.734   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.735 LLM extraction (async)
# 14:28:56.736   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.737 LLM extraction (async)
# 14:28:56.738   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.739 LLM extraction (async)
# 14:28:56.741   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.742 LLM extraction (async)
# 14:28:56.743   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.745 LLM extraction (async)
# 14:28:56.746   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.748 LLM extraction (async)
# 14:28:56.750   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.751 LLM extraction (async)
# 14:28:56.752   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.753 LLM extraction (async)
# 14:28:56.754   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.755 LLM extraction (async)
# 14:28:56.756   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.757 LLM extraction (async)
# 14:28:56.759   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.760 LLM extraction (async)
# 14:28:56.762   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.763 LLM extraction (async)
# 14:28:56.764   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.766 LLM extraction (async)
# 14:28:56.767   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.768 LLM extraction (async)
# 14:28:56.769   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.770 LLM extraction (async)
# 14:28:56.771   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.772 LLM extraction (async)
# 14:28:56.774   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.776 LLM extraction (async)
# 14:28:56.779   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.780 LLM extraction (async)
# 14:28:56.782   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.784 LLM extraction (async)
# 14:28:56.786   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.787 LLM extraction (async)
# 14:28:56.788   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.789 LLM extraction (async)
# 14:28:56.791   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.792 LLM extraction (async)
# 14:28:56.793   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.795 LLM extraction (async)
# 14:28:56.796   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.798 LLM extraction (async)
# 14:28:56.800   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.801 LLM extraction (async)
# 14:28:56.802   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.803 LLM extraction (async)
# 14:28:56.804   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.805 LLM extraction (async)
# 14:28:56.806   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.807 LLM extraction (async)
# 14:28:56.809   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.810 LLM extraction (async)
# 14:28:56.812   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.813 LLM extraction (async)
# 14:28:56.815   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.816 LLM extraction (async)
# 14:28:56.819   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.820 LLM extraction (async)
# 14:28:56.821   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.822 LLM extraction (async)
# 14:28:56.824   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.826 LLM extraction (async)
# 14:28:56.828   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.830 LLM extraction (async)
# 14:28:56.834   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.836 LLM extraction (async)
# 14:28:56.838   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.839 LLM extraction (async)
# 14:28:56.842   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.847 LLM extraction (async)
# 14:28:56.849   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.852 LLM extraction (async)
# 14:28:56.854   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.859 LLM extraction (async)
# 14:28:56.863   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.866 LLM extraction (async)
# 14:28:56.869   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.870 LLM extraction (async)
# 14:28:56.873   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.877 LLM extraction (async)
# 14:28:56.879   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.882 LLM extraction (async)
# 14:28:56.885   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.887 LLM extraction (async)
# 14:28:56.889   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.891 LLM extraction (async)
# 14:28:56.895   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.899 LLM extraction (async)
# 14:28:56.902   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.906 LLM extraction (async)
# 14:28:56.909   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.912 LLM extraction (async)
# 14:28:56.915   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.916 LLM extraction (async)
# 14:28:56.919   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.920 LLM extraction (async)
# 14:28:56.921   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.923 LLM extraction (async)
# 14:28:56.926   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.928 LLM extraction (async)
# 14:28:56.930   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.932 LLM extraction (async)
# 14:28:56.934   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.935 LLM extraction (async)
# 14:28:56.937   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.938 LLM extraction (async)
# 14:28:56.940   Chat Completion with 'gpt-oss' [LLM]
# 14:28:56.942 LLM extraction (async)
# 14:28:56.945   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:07.293   FAST API lookup
# 14:29:08.174   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:11.085   FAST API lookup
# 14:29:12.044   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:12.094   FAST API lookup
# 14:29:12.952   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:12.970   FAST API lookup
# 14:29:14.003   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:14.014   FAST API lookup
# 14:29:14.247   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:14.268   FAST API lookup
# 14:29:15.115   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:15.128   FAST API lookup
# 14:29:16.068   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:16.082   FAST API lookup
# 14:29:18.869   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:18.883   FAST API lookup
# 14:29:19.740   Unexpected error: Expecting value: line 1 column 1 (char 0)
#              │ json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#              │ Traceback (most recent call last):
#              │   File "/home/tdpearson/consulting/varun/oclc_cleanup/scripts/utils.py", line 175, in extract_async
#              │     result = assignFast(**args)
#              │   File "/home/tdpearson/consulting/varun/oclc_cleanup/scripts/agenttools.py", line 36, in assignFast
#              │     data = resp.json()
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/site-packages/httpx/_models.py", line 832, in json
#              │     return jsonlib.loads(self.content, **kwargs)
#              │            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/json/__init__.py", line 352, in loads
#              │     return _default_decoder.decode(s)
#              │            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/json/decoder.py", line 345, in decode
#              │     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#              │                ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/json/decoder.py", line 363, in raw_decode
#              │     raise JSONDecodeError("Expecting value", s, err.value) from None
#              │ json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# 14:29:19.747   Pydantic OclcFast validate_json
#              LLM extraction (async)
# 14:29:19.765   FAST API lookup
# 14:29:20.526   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:20.541   FAST API lookup
# 14:29:21.382   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:21.498   FAST API lookup
# 14:29:22.264   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:22.274   FAST API lookup
# 14:29:23.086   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:23.099   FAST API lookup
# 14:29:23.841   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:23.857   FAST API lookup
# 14:29:24.662   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:24.674   FAST API lookup
# 14:29:27.626   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:27.636   FAST API lookup
# 14:29:30.345   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:30.357   FAST API lookup
# 14:29:31.214   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:31.228   FAST API lookup
# 14:29:32.100   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:32.113   FAST API lookup
# 14:29:32.883   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:32.896   FAST API lookup
# 14:29:33.773   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:33.791   FAST API lookup
# 14:29:37.153   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:37.168   FAST API lookup
# 14:29:37.926   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:37.971   FAST API lookup
# 14:29:38.740   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:38.753   FAST API lookup
# 14:29:39.610   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:39.621   FAST API lookup
# 14:29:40.362   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:40.371   FAST API lookup
# 14:29:42.784   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:42.802   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:42.815   FAST API lookup
# 14:29:43.666   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:43.682   FAST API lookup
# 14:29:44.441   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:44.454   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:44.462   FAST API lookup
# 14:29:45.261   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:45.274   FAST API lookup
# 14:29:48.088   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:48.099   FAST API lookup
# 14:29:48.929   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:48.944   FAST API lookup
# 14:29:49.749   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:49.763   FAST API lookup
# 14:29:50.566   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:50.579   FAST API lookup
# 14:29:51.386   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:51.397   FAST API lookup
# 14:29:54.036   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:54.048   FAST API lookup
# 14:29:54.339   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:54.353   FAST API lookup
# 14:29:55.173   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:55.185   FAST API lookup
# 14:29:56.101   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:56.113   FAST API lookup
# 14:29:59.169   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:29:59.182   FAST API lookup
# 14:29:59.987   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:00.005   FAST API lookup
# 14:30:01.115   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:01.128   FAST API lookup
# 14:30:01.951   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:01.963   FAST API lookup
# 14:30:02.752   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:02.768   FAST API lookup
# 14:30:06.091   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:06.111   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:06.129   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:06.145   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:06.157   FAST API lookup
# 14:30:08.690   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:08.704   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:08.719   FAST API lookup
# 14:30:09.518   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:09.531   FAST API lookup
# 14:30:10.263   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:10.275   FAST API lookup
# 14:30:11.049   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:11.064   FAST API lookup
# 14:30:11.928   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:11.944   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:12.019   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:12.036   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:12.048   FAST API lookup
# 14:30:12.903   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:12.928   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:12.947   FAST API lookup
# 14:30:13.718   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:13.735   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:13.745   FAST API lookup
# 14:30:14.634   Chat Completion with 'gpt-oss' [LLM]
# 14:30:14.661 LLM extraction (async)
# 14:30:14.666   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:14.685   FAST API lookup
# 14:30:15.438   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:15.451   FAST API lookup
# 14:30:17.394   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:17.405   FAST API lookup
# 14:30:18.214   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:18.223   FAST API lookup
# 14:30:20.694   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:20.706   FAST API lookup
# 14:30:21.800   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:21.909   FAST API lookup
# 14:30:22.658   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:22.668   FAST API lookup
# 14:30:25.849   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:25.864   FAST API lookup
# 14:30:26.599   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:26.609   FAST API lookup
# 14:30:27.366   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:27.380   FAST API lookup
# 14:30:30.292   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:30.305   FAST API lookup
# 14:30:33.064   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:33.075   FAST API lookup
# 14:30:33.830   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:33.844   FAST API lookup
# 14:30:34.588   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:34.604   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:34.624   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:34.688   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:34.702   FAST API lookup
# 14:30:35.451   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:35.468   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:35.487   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:35.504   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:35.515   FAST API lookup
# 14:30:36.383   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:36.395   FAST API lookup
# 14:30:38.999   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:39.014   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:39.031   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:39.040   FAST API lookup
# 14:30:40.028   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:40.039   FAST API lookup
# 14:30:40.847   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:40.861   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:40.875   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:40.888   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:41.027   FAST API lookup
# 14:30:41.869   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:47.100   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:47.907   FAST API lookup
# 14:30:48.731   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:48.746   FAST API lookup
# 14:30:49.532   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:49.552   FAST API lookup
# 14:30:50.489   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:50.503   FAST API lookup
# 14:30:51.287   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:51.299   FAST API lookup
# 14:30:52.117   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:52.130   FAST API lookup
# 14:30:52.856   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:52.868   FAST API lookup
# 14:30:54.670   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:54.683   FAST API lookup
# 14:30:55.437   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:55.490   FAST API lookup
# 14:30:55.750   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:55.764   FAST API lookup
# 14:30:56.516   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:56.533   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:56.545   FAST API lookup
# 14:30:57.310   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:30:57.321   FAST API lookup
# 14:31:00.476   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:00.489   FAST API lookup
# 14:31:03.384   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:03.388   FAST API lookup
# 14:31:04.192   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:04.203   FAST API lookup
# 14:31:04.945   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:04.954   FAST API lookup
# 14:31:08.593   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:08.601   FAST API lookup
# 14:31:11.055   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:11.073   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:11.186   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:11.203   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:11.219   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:11.236   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:11.255   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:11.275   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:11.289   FAST API lookup
# 14:31:12.056   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:12.072   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:12.086   FAST API lookup
# 14:31:13.007   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:13.020   FAST API lookup
# 14:31:13.783   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:13.791   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:13.799   FAST API lookup
# 14:31:14.575   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:14.589   FAST API lookup
# 14:31:15.357   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:15.420   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:15.430   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:15.439   FAST API lookup
# 14:31:16.199   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:16.207   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:16.216   FAST API lookup
# 14:31:16.988   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:16.997   FAST API lookup
# 14:31:17.818   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:17.837   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:17.844   FAST API lookup
# 14:31:18.094   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:18.102   FAST API lookup
# 14:31:19.671   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:19.677   FAST API lookup
# 14:31:20.434   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:20.441   FAST API lookup
# 14:31:21.295   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:21.305   FAST API lookup
# 14:31:24.388   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:24.396   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:24.404   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:24.409   FAST API lookup
# 14:31:25.388   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:25.393   FAST API lookup
# 14:31:25.639   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:25.649   FAST API lookup
# 14:31:26.421   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:26.430   FAST API lookup
# 14:31:29.074   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:29.084   FAST API lookup
# 14:31:29.891   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:29.899   FAST API lookup
# 14:31:30.649   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:30.657   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:30.662   FAST API lookup
# 14:31:31.521   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:31.528   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:31.534   FAST API lookup
# 14:31:33.866   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:33.872   FAST API lookup
# 14:31:34.585   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:34.593   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:34.600   FAST API lookup
# 14:31:35.938   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:35.953   FAST API lookup
# 14:31:36.753   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:36.760   FAST API lookup
# 14:31:37.491   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:37.503   FAST API lookup
# 14:31:40.651   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:40.671   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:40.690   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:40.702   FAST API lookup
# 14:31:41.529   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:41.551   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:41.568   FAST API lookup
# 14:31:43.043   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:43.056   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:43.064   FAST API lookup
# 14:31:43.812   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:43.822   FAST API lookup
# 14:31:45.054   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:45.071   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:45.084   FAST API lookup
# 14:31:45.827   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:45.841   FAST API lookup
# 14:31:46.684   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:46.703   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:46.719   FAST API lookup
# 14:31:47.488   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:47.497   FAST API lookup
# 14:31:48.328   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:48.349   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:48.365   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:48.375   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:48.388   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:48.398   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:48.405   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:48.413   FAST API lookup
# 14:31:50.843   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:50.861   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:50.874   FAST API lookup
# 14:31:51.708   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:51.728   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:51.743   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:51.760   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:51.778   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:51.790   FAST API lookup
# 14:31:52.562   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:52.578   FAST API lookup
# 14:31:53.366   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:53.377   FAST API lookup
# 14:31:54.168   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:54.182   FAST API lookup
# 14:31:54.973   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:55.035   FAST API lookup
# 14:31:55.821   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:55.833   FAST API lookup
# 14:31:56.731   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:56.749   FAST API lookup
# 14:31:57.726   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:31:57.752   FAST API lookup
# 14:31:58.488   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:04.619   FAST API lookup
# 14:32:06.909   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:06.938   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:06.952   FAST API lookup
# 14:32:07.752   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:07.764   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:07.772   FAST API lookup
# 14:32:08.521   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:08.532   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:08.539   FAST API lookup
# 14:32:09.305   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:09.313   FAST API lookup
# 14:32:10.071   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:10.177   FAST API lookup
# 14:32:12.275   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:12.290   FAST API lookup
# 14:32:13.023   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:13.048   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:13.061   FAST API lookup
# 14:32:14.034   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:14.046   FAST API lookup
# 14:32:14.795   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:14.814   FAST API lookup
# 14:32:15.564   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:15.588   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:15.600   FAST API lookup
# 14:32:18.988   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:19.001   FAST API lookup
# 14:32:22.875   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:22.888   FAST API lookup
# 14:32:23.658   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:23.676   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:23.696   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:23.708   FAST API lookup
# 14:32:24.989   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:25.008   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:25.025   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:25.036   FAST API lookup
# 14:32:25.809   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:25.827   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:25.838   FAST API lookup
# 14:32:26.629   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:26.643   FAST API lookup
# 14:32:27.422   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:27.434   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:27.515   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:27.533   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:27.544   FAST API lookup
# 14:32:28.298   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:28.317   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:28.399   FAST API lookup
# 14:32:29.294   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:29.309   FAST API lookup
# 14:32:30.678   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:30.694   FAST API lookup
# 14:32:32.774   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:32.789   FAST API lookup
# 14:32:33.588   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:33.604   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:33.620   FAST API lookup
# 14:32:34.361   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:34.373   FAST API lookup
# 14:32:36.812   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:36.825   FAST API lookup
# 14:32:37.686   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:37.695   FAST API lookup
# 14:32:38.541   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:38.598   FAST API lookup
# 14:32:39.531   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:39.544   FAST API lookup
# 14:32:40.293   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:40.306   FAST API lookup
# 14:32:43.010   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:43.021   FAST API lookup
# 14:32:43.788   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:43.800   FAST API lookup
# 14:32:45.269   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:45.283   FAST API lookup
# 14:32:46.065   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:46.076   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:46.095   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:46.106   FAST API lookup
# 14:32:46.906   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:46.920   FAST API lookup
# 14:32:48.053   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:48.061   FAST API lookup
# 14:32:48.848   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:48.864   FAST API lookup
# 14:32:49.770   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:49.788   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:49.805   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:49.820   FAST API lookup
# 14:32:52.608   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:52.625   FAST API lookup
# 14:32:53.456   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:53.470   FAST API lookup
# 14:32:54.376   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:54.392   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:54.403   FAST API lookup
# 14:32:56.199   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:56.210   FAST API lookup
# 14:32:56.937   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:56.951   FAST API lookup
# 14:32:57.856   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:57.863   FAST API lookup
# 14:32:59.397   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:32:59.411   FAST API lookup
# 14:33:00.164   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:00.176   FAST API lookup
# 14:33:00.942   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:00.968   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:00.979   FAST API lookup
# 14:33:02.160   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:02.174   FAST API lookup
# 14:33:02.438   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:02.456   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:02.470   FAST API lookup
# 14:33:03.289   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:03.301   FAST API lookup
# 14:33:04.062   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:04.083   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:04.102   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:04.112   FAST API lookup
# 14:33:05.030   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:05.041   FAST API lookup
# 14:33:06.054   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:06.074   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:06.086   FAST API lookup
# 14:33:06.975   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:06.987   FAST API lookup
# 14:33:07.790   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:07.804   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:07.812   FAST API lookup
# 14:33:08.589   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:08.600   FAST API lookup
# 14:33:09.432   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:09.447   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:09.460   FAST API lookup
# 14:33:12.206   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:12.224   FAST API lookup
# 14:33:12.966   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:12.990   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:13.010   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:13.024   FAST API lookup
# 14:33:13.848   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:13.865   FAST API lookup
# 14:33:14.610   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:14.627   FAST API lookup
# 14:33:15.423   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:15.437   FAST API lookup
# 14:33:16.300   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:16.352   FAST API lookup
# 14:33:17.831   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:17.840   FAST API lookup
# 14:33:18.648   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:18.659   FAST API lookup
# 14:33:20.812   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:20.880   FAST API lookup
# 14:33:21.724   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:21.736   FAST API lookup
# 14:33:22.541   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:22.561   FAST API lookup
# 14:33:23.444   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:23.490   FAST API lookup
# 14:33:24.303   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:30.018   FAST API lookup
# 14:33:30.840   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:30.857   FAST API lookup
# 14:33:31.653   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:31.666   FAST API lookup
# 14:33:32.575   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:32.595   FAST API lookup
# 14:33:33.364   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:33.376   FAST API lookup
# 14:33:34.326   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:34.339   FAST API lookup
# 14:33:35.238   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:35.266   FAST API lookup
# 14:33:36.015   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:36.028   FAST API lookup
# 14:33:37.285   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:37.296   FAST API lookup
# 14:33:38.037   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:38.047   FAST API lookup
# 14:33:38.803   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:38.883   FAST API lookup
# 14:33:40.339   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:40.358   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:40.370   FAST API lookup
# 14:33:42.508   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:42.531   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:42.543   FAST API lookup
# 14:33:43.301   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:43.328   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:43.340   FAST API lookup
# 14:33:44.086   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:44.106   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:44.117   FAST API lookup
# 14:33:44.968   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:44.983   FAST API lookup
# 14:33:45.730   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:45.747   FAST API lookup
# 14:33:46.706   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:46.816   FAST API lookup
# 14:33:49.227   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:49.240   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:49.250   FAST API lookup
# 14:33:50.087   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:50.101   FAST API lookup
# 14:33:50.904   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:50.924   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:50.936   FAST API lookup
# 14:33:53.927   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:53.941   FAST API lookup
# 14:33:54.689   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:54.797   FAST API lookup
# 14:33:55.102   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:55.114   FAST API lookup
# 14:33:57.766   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:57.774   FAST API lookup
# 14:33:58.003   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:58.014   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:58.025   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:58.034   FAST API lookup
# 14:33:58.794   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:58.806   FAST API lookup
# 14:33:59.572   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:33:59.585   FAST API lookup
# 14:34:00.321   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:00.336   FAST API lookup
# 14:34:01.243   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:01.252   FAST API lookup
# 14:34:01.490   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:01.500   FAST API lookup
# 14:34:02.370   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:02.380   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:02.390   FAST API lookup
# 14:34:04.622   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:04.629   FAST API lookup
# 14:34:05.455   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:05.461   FAST API lookup
# 14:34:06.209   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:06.217   FAST API lookup
# 14:34:09.334   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:09.340   FAST API lookup
# 14:34:10.244   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:10.263   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:10.277   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:10.293   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:10.304   FAST API lookup
# 14:34:11.279   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:11.302   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:11.314   FAST API lookup
# 14:34:12.053   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:12.065   FAST API lookup
# 14:34:12.875   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:12.890   FAST API lookup
# 14:34:13.639   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:13.654   FAST API lookup
# 14:34:16.415   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:16.430   FAST API lookup
# 14:34:17.225   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:17.241   FAST API lookup
# 14:34:18.041   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:18.060   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:18.070   FAST API lookup
# 14:34:18.854   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:18.866   FAST API lookup
# 14:34:19.792   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:19.813   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:19.827   FAST API lookup
# 14:34:20.692   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:34:20.719   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# ...
#              │     result = assignFast(**args)
#              │   File "/home/tdpearson/consulting/varun/oclc_cleanup/scripts/agenttools.py", line 36, in assignFast
#              │     data = resp.json()
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/site-packages/httpx/_models.py", line 832, in json
#              │     return jsonlib.loads(self.content, **kwargs)
#              │            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/json/__init__.py", line 352, in loads
#              │     return _default_decoder.decode(s)
#              │            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/json/decoder.py", line 345, in decode
#              │     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#              │                ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/json/decoder.py", line 363, in raw_decode
#              │     raise JSONDecodeError("Expecting value", s, err.value) from None
#              │ json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# 14:40:06.913   Pydantic OclcFast validate_json
#              LLM extraction (async)
# 14:40:06.936   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:06.959   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:06.974   FAST API lookup
# 14:40:07.711   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:07.716   FAST API lookup
# 14:40:08.484   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:08.495   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:08.500   FAST API lookup
# 14:40:09.278   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:09.292   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:09.301   FAST API lookup
# 14:40:10.246   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:10.261   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:10.272   FAST API lookup
# 14:40:13.350   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:13.429   FAST API lookup
# 14:40:13.714   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:13.732   FAST API lookup
# 14:40:14.479   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:14.495   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:14.516   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:14.527   FAST API lookup
# 14:40:17.608   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:17.622   FAST API lookup
# 14:40:18.387   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:18.407   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:18.421   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:18.437   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:18.452   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:18.457   FAST API lookup
# 14:40:19.226   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:19.244   FAST API lookup
# 14:40:20.033   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:20.042   FAST API lookup
# 14:40:20.778   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:20.789   FAST API lookup
# 14:40:24.446   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:24.458   FAST API lookup
# 14:40:25.233   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:25.257   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:25.270   FAST API lookup
# 14:40:26.069   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:26.094   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:26.107   FAST API lookup
# 14:40:26.851   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:26.868   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:26.876   FAST API lookup
# 14:40:27.637   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:27.648   FAST API lookup
# 14:40:29.022   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:29.043   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:29.133   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:29.146   FAST API lookup
# 14:40:29.916   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:29.955   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:29.983   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:30.016   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:30.036   FAST API lookup
# 14:40:32.598   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:32.635   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:32.650   FAST API lookup
# 14:40:33.455   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:33.479   FAST API lookup
# 14:40:34.252   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:34.287   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:34.324   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:34.359   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:34.393   FAST API lookup
# 14:40:34.677   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:34.705   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:34.729   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:34.754   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:34.774   Chat Completion with 'gpt-oss' [LLM]
# 14:40:34.803 LLM extraction (async)
# 14:40:34.806   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:34.854   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:34.872   FAST API lookup
# 14:40:35.603   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:35.611   FAST API lookup
# 14:40:36.439   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:36.461   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:36.469   FAST API lookup
# 14:40:37.334   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:37.348   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:37.356   FAST API lookup
# 14:40:38.096   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:38.108   FAST API lookup
# 14:40:39.041   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:39.046   FAST API lookup
# 14:40:41.547   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:41.562   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:41.568   Pydantic OclcFast validate_json
#              LLM extraction (async)
# 14:40:41.588   FAST API lookup
# 14:40:42.328   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:46.137   FAST API lookup
# 14:40:47.063   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:49.007   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:50.025   FAST API lookup
# 14:40:50.952   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:50.962   FAST API lookup
# 14:40:51.717   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:51.725   FAST API lookup
# 14:40:52.471   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:52.496   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:52.519   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:52.535   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:52.542   FAST API lookup
# 14:40:53.310   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:53.316   FAST API lookup
# 14:40:54.130   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:54.172   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:54.182   FAST API lookup
# 14:40:54.949   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:54.961   FAST API lookup
# 14:40:55.677   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:55.685   FAST API lookup
# 14:40:56.483   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:56.518   FAST API lookup
# 14:40:57.272   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:57.287   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:57.301   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:57.306   FAST API lookup
# 14:40:58.060   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:58.073   FAST API lookup
# 14:40:58.815   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:58.829   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:58.843   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:58.852   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:58.858   FAST API lookup
# 14:40:59.656   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:40:59.666   FAST API lookup
# 14:41:01.594   Unexpected error: Expecting value: line 1 column 1 (char 0)
#              │ json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#              │ Traceback (most recent call last):
#              │   File "/home/tdpearson/consulting/varun/oclc_cleanup/scripts/utils.py", line 175, in extract_async
#              │     result = assignFast(**args)
#              │   File "/home/tdpearson/consulting/varun/oclc_cleanup/scripts/agenttools.py", line 36, in assignFast
#              │     data = resp.json()
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/site-packages/httpx/_models.py", line 832, in json
#              │     return jsonlib.loads(self.content, **kwargs)
#              │            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/json/__init__.py", line 352, in loads
#              │     return _default_decoder.decode(s)
#              │            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/json/decoder.py", line 345, in decode
#              │     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#              │                ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/json/decoder.py", line 363, in raw_decode
#              │     raise JSONDecodeError("Expecting value", s, err.value) from None
#              │ json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# 14:41:01.595   Pydantic OclcFast validate_json
#              LLM extraction (async)
# 14:41:01.611   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:01.619   FAST API lookup
# 14:41:02.351   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:02.369   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:02.386   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:02.407   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:02.424   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:02.429   FAST API lookup
# 14:41:05.033   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:05.045   FAST API lookup
# 14:41:05.794   Unexpected error: Expecting value: line 1 column 1 (char 0)
#              │ json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#              │ Traceback (most recent call last):
#              │   File "/home/tdpearson/consulting/varun/oclc_cleanup/scripts/utils.py", line 175, in extract_async
#              │     result = assignFast(**args)
#              │   File "/home/tdpearson/consulting/varun/oclc_cleanup/scripts/agenttools.py", line 36, in assignFast
#              │     data = resp.json()
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/site-packages/httpx/_models.py", line 832, in json
#              │     return jsonlib.loads(self.content, **kwargs)
#              │            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/json/__init__.py", line 352, in loads
#              │     return _default_decoder.decode(s)
#              │            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/json/decoder.py", line 345, in decode
#              │     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#              │                ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#              │   File "/home/tdpearson/miniforge3/lib/python3.13/json/decoder.py", line 363, in raw_decode
#              │     raise JSONDecodeError("Expecting value", s, err.value) from None
#              │ json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# 14:41:05.798   Pydantic OclcFast validate_json
#              LLM extraction (async)
# 14:41:05.810   FAST API lookup
# 14:41:06.112   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:06.123   FAST API lookup
# 14:41:06.934   Chat Completion with 'gpt-oss' [LLM]
# 14:41:07.045 LLM extraction (async)
# 14:41:07.049   Chat Completion with 'gpt-oss' [LLM]
# 14:41:07.054 LLM extraction (async)
# 14:41:07.058   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:07.083   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:07.105   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:07.119   FAST API lookup
# 14:41:07.881   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:07.898   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:07.904   FAST API lookup
# 14:41:08.671   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:08.692   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:08.706   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:08.719   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:08.732   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:08.740   FAST API lookup
# 14:41:09.597   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:09.610   FAST API lookup
# 14:41:10.368   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:10.378   FAST API lookup
# 14:41:11.114   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:11.126   FAST API lookup
# 14:41:13.617   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:13.636   Chat Completion with 'gpt-oss' [LLM]
#              LLM extraction (async)
# 14:41:13.642   FAST API lookup

# %%
loaded_data.to_csv("../data/output/metadata.csv", index=False)

# %%
loaded_data
